# %% [markdown]
# Data Info and Import Data Intro Box

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Swiggy_50.csv')

# %%
df.head(11)
# Out:
#                    Restaurant Name  \
# 0                              KFC
# 1                       McDonald's
# 2                       Haldiram's
# 3                       Chai Point
# 4        Bikanervala Chandni Chowk
# 5                 La Pino'z Pizza
# 6                      Burger King
# 7        Chaayos Chai+Snacks=Relax
# 8                Capten Milkshakes
# 9          The Brijwasi Restaurant
# 10  Great Indian Khichdi by EatFit
#
#                                              Category  Rating  Cost for two  \
# 0                             American,Snacks,Biryani     3.9           400
# 1                                            American     4.3           400
# 2                          Sweets,Snacks,North Indian     4.0           350
# 3   Bakery,Beverages,Maharashtrian,Snacks,Street F...     4.2           150
# 4                                  Street Food,Sweets     4.1           400
# 5   Italian,Pizzas,Fast Food,Mexican,Desserts,Beve...     3.7           250
# ...

# %%
df.tail(11)
# Out:
#                           Restaurant Name  \
# 31793                   Chinese 'X' Press
# 31794                            PVR Cafe
# 31795                            Yo Dhaba
# 31796                          Pizza Club
# 31797                        The LoveKing
# 31798    Om Kaleshwar Sweets & Bhojnalaya
# 31799  Khukri Desi Mutton & Chicken Point
# 31800                    Monis Restaurant
# 31801                T3 Tasty Table Talks
# 31802                     The Green Lemon
# 31803                     Pizza Home City
#
#                                                 Category  Rating  \
# 31793                                            Chinese     3.6
# 31794                         Snacks,Fast Food,Beverages     NaN
# 31795                                       North Indian     NaN
# 31796                                     Pizzas,Italian     NaN
# 31797                                  Fast Food,Italian     NaN
# ...

# %% [markdown]
# Cleaning Data Box 1

# %%
col_headers = list(df.columns)
num_of_cols = len(list(df.columns))
print("There are",num_of_cols,"coumns in the dataframe. Let's take look at names of those columns")
print()
print(col_headers)

# df.shape
# Out:
# There are 10 coumns in the dataframe. Let's take look at names of those columns
#
# ['Restaurant Name', 'Category', 'Rating', 'Cost for two', 'Veg', 'city', 'Area', 'Locality', 'Address', 'Long Distance Delivery']

# %% [markdown]
# Cleaning Data Box 1

# %%
df = df[['Restaurant Name', 'Category', 'Rating', 'Cost for two', 'Veg', 'city']]
df = df[df['city'] == 'Delhi'] ## narrows our focus just on restaurants in Delhi
df = df.dropna()
print(df.head(5))
print(df.tail(5))
# Out:
#              Restaurant Name  \
# 0                        KFC
# 1                 McDonald's
# 2                 Haldiram's
# 3                 Chai Point
# 4  Bikanervala Chandni Chowk
#
#                                             Category  Rating  Cost for two  \
# 0                            American,Snacks,Biryani     3.9           400
# 1                                           American     4.3           400
# 2                         Sweets,Snacks,North Indian     4.0           350
# 3  Bakery,Beverages,Maharashtrian,Snacks,Street F...     4.2           150
# 4                                 Street Food,Sweets     4.1           400
#
#      Veg   city
# 0  False  Delhi
# 1  False  Delhi
# 2   True  Delhi
# 3  False  Delhi
# 4  False  Delhi
#                    Restaurant Name                   Category  Rating  \
# 1401  PUNIKAR'S Mumbai Street Food               South Indian     4.6
# 1406                  Satnam Rasoi                     Indian     3.7
# ...

# %% [markdown]
# Plot Data Box 1

# %%
x = np.array(df['Cost for two'])
y = np.array(df['Rating'])
plt.figure(figsize=(15,7))
plt.scatter(x, y)
plt.title("Is it more expensive go to a nice place?", fontweight ="bold", color ="black")
plt.xlabel("Cost for Two in Rupees", fontweight ="bold", color ="black")
plt.ylabel("Rating on Scale 0 to 5", fontweight ="bold", color ="black")
plt.xticks(fontsize= 10, color ="black")
plt.yticks(fontsize= 10, color ="black")
plt.show()

# %% [markdown]
# Data Inisght Box 1

# %% [markdown]
# CLeaning Data Box2 Percent of Vegetarin Options in Delhi

# %%
df2 = df2[['Restaurant Name','Veg', 'city']]
df2 = df2[df2['city'] == 'Delhi'] ## narrows our focus just on restaurants in Delhi
df2 = df2.dropna()
print(df2.head(5))
print(df2.tail(5))
# Out:
#              Restaurant Name    Veg   city
# 0                        KFC  False  Delhi
# 1                 McDonald's  False  Delhi
# 2                 Haldiram's   True  Delhi
# 3                 Chai Point  False  Delhi
# 4  Bikanervala Chandni Chowk  False  Delhi
#                    Restaurant Name    Veg   city
# 1401  PUNIKAR'S Mumbai Street Food  False  Delhi
# 1406                  Satnam Rasoi  False  Delhi
# 1410                  Burger House  False  Delhi
# 1413               THE BIRYANI INC  False  Delhi
# 1420                New Gole Hatti   True  Delhi

# %%
df2
# Out:
#                    Restaurant Name    Veg   city
# 0                              KFC  False  Delhi
# 1                       McDonald's  False  Delhi
# 2                       Haldiram's   True  Delhi
# 3                       Chai Point  False  Delhi
# 4        Bikanervala Chandni Chowk  False  Delhi
# ...                            ...    ...    ...
# 1401  PUNIKAR'S Mumbai Street Food  False  Delhi
# 1406                  Satnam Rasoi  False  Delhi
# 1410                  Burger House  False  Delhi
# 1413               THE BIRYANI INC  False  Delhi
# 1420                New Gole Hatti   True  Delhi
#
# [583 rows x 3 columns]

# %% [markdown]
# Summerize Vegeterain Options

# %% [markdown]
# Display True and False Data

# %%
df2['Veg'].value_counts()
# Out:
# False    406
# True     177
# Name: Veg, dtype: int64

# %% [markdown]
# Plot Pie Graph of Vegetarian Options

# %%
df2_sub = pd.DataFrame({'True': [177],'False': [406]}, index=['Vegetarian Only', 'Not Vegetarian'])
plot = df2_sub.plot.pie(y='True', figsize=(5, 5))

# %% [markdown]
# Data Insight Box 2

# %% [markdown]
# CLeaning Data Box3 Percent of Vegetarin Options in Delhi
